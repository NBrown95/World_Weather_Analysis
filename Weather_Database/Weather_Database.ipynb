# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests 
from citipy import citipy
from config import weather_database_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_database_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d12c5a242c476a88e7e9849310b75fdb

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | hamilton
# Processing Record 5 of Set 1 | san patricio
# Processing Record 6 of Set 1 | jiwani
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | quatre cocos
# Processing Record 9 of Set 1 | manono
# Processing Record 10 of Set 1 | berdigestyakh
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 1 | fort-shevchenko
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | libreville
# Processing Record 19 of Set 1 | bhabua
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | silver city
# Processing Record 24 of Set 1 | mafinga
# Processing Record 25 of Set 1 | janakpur
# Processing Record 26 of Set 1 | tabou
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | sibu
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | ambulu
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | guadalupe y calvo
# Processing Record 36 of Set 1 | alappuzha
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | sur
# Processing Record 39 of Set 1 | santa marta
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | kutum
# Processing Record 43 of Set 1 | dingli
# Processing Record 44 of Set 1 | mulege
# Processing Record 45 of Set 1 | husavik
# Processing Record 46 of Set 1 | auki
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | newport
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | lavrentiya
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | lypova dolyna
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | bijie
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | sembe
# Processing Record 10 of Set 2 | korla
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 2 | saint-pierre
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | srednekolymsk
# Processing Record 19 of Set 2 | domoni
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | pallasovka
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | tobermory
# Processing Record 24 of Set 2 | liku
# Processing Record 25 of Set 2 | asfi
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | manta
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | fontem
# Processing Record 36 of Set 2 | mongagua
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | mayskiy
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | morro bay
# Processing Record 41 of Set 2 | otradnoye
# Processing Record 42 of Set 2 | aksarayskiy
# Processing Record 43 of Set 2 | puerto escondido
# Processing Record 44 of Set 2 | chilca
# Processing Record 45 of Set 2 | harindanga
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | elko
# Processing Record 48 of Set 2 | tuburan
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-georges
# Processing Record 2 of Set 3 | alvorada
# Processing Record 3 of Set 3 | kamra
# Processing Record 4 of Set 3 | egvekinot
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | perth
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | puerto quijarro
# Processing Record 9 of Set 3 | sitrah
# Processing Record 10 of Set 3 | makakilo city
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | toora-khem
# Processing Record 13 of Set 3 | nemuro
# Processing Record 14 of Set 3 | soyo
# Processing Record 15 of Set 3 | swinoujscie
# Processing Record 16 of Set 3 | mahon
# Processing Record 17 of Set 3 | matara
# Processing Record 18 of Set 3 | sultanpur
# Processing Record 19 of Set 3 | fairmont
# Processing Record 20 of Set 3 | yellapur
# Processing Record 21 of Set 3 | sao lourenco do sul
# Processing Record 22 of Set 3 | provideniya
# Processing Record 23 of Set 3 | ostrovnoy
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | comodoro rivadavia
# Processing Record 27 of Set 3 | safranbolu
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | erenhot
# Processing Record 30 of Set 3 | montemor-o-novo
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | craig
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | porteirinha
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | igrim
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | tautira
# Processing Record 41 of Set 3 | odweyne
# Processing Record 42 of Set 3 | bellavista
# Processing Record 43 of Set 3 | sale
# Processing Record 44 of Set 3 | bilibino
# Processing Record 45 of Set 3 | bagamoyo
# Processing Record 46 of Set 3 | bouna
# Processing Record 47 of Set 3 | ponta delgada
# Processing Record 48 of Set 3 | dubbo
# Processing Record 49 of Set 3 | namatanai
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | yellowknife
# Processing Record 3 of Set 4 | tabatinga
# Processing Record 4 of Set 4 | petrovskaya
# Processing Record 5 of Set 4 | san luis
# Processing Record 6 of Set 4 | lasa
# Processing Record 7 of Set 4 | ancud
# Processing Record 8 of Set 4 | lichinga
# Processing Record 9 of Set 4 | canaries
# Processing Record 10 of Set 4 | boueni
# Processing Record 11 of Set 4 | gigant
# Processing Record 12 of Set 4 | kinanah
# City not found. Skipping...
# Processing Record 13 of Set 4 | ionia
# Processing Record 14 of Set 4 | dalton
# Processing Record 15 of Set 4 | brae
# Processing Record 16 of Set 4 | russell
# Processing Record 17 of Set 4 | marawi
# Processing Record 18 of Set 4 | ocampo
# Processing Record 19 of Set 4 | clyde river
# Processing Record 20 of Set 4 | caluquembe
# Processing Record 21 of Set 4 | launceston
# Processing Record 22 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 4 | kirakira
# Processing Record 24 of Set 4 | nuevitas
# Processing Record 25 of Set 4 | wuda
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | pingshan
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | coahuayana
# Processing Record 31 of Set 4 | prince george
# Processing Record 32 of Set 4 | camacupa
# Processing Record 33 of Set 4 | alice springs
# Processing Record 34 of Set 4 | ribeira grande
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | umm kaddadah
# Processing Record 37 of Set 4 | chapais
# Processing Record 38 of Set 4 | lebork
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | maihar
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | laguna
# Processing Record 43 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | pitimbu
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | nioro
# Processing Record 48 of Set 4 | margate
# Processing Record 49 of Set 4 | harper
# Processing Record 50 of Set 4 | green valley
# Processing Record 1 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | itarema
# Processing Record 4 of Set 5 | valparaiso
# Processing Record 5 of Set 5 | moron
# Processing Record 6 of Set 5 | arawa
# Processing Record 7 of Set 5 | te kauwhata
# Processing Record 8 of Set 5 | flores
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | tromso
# Processing Record 13 of Set 5 | castro
# Processing Record 14 of Set 5 | znamenskoye
# Processing Record 15 of Set 5 | marshall
# Processing Record 16 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 5 | ban nahin
# Processing Record 18 of Set 5 | la union
# Processing Record 19 of Set 5 | djambala
# Processing Record 20 of Set 5 | aquiraz
# Processing Record 21 of Set 5 | finspang
# Processing Record 22 of Set 5 | aklavik
# Processing Record 23 of Set 5 | naruja
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | harer
# Processing Record 27 of Set 5 | tevriz
# Processing Record 28 of Set 5 | lahuachaca
# Processing Record 29 of Set 5 | san ramon
# Processing Record 30 of Set 5 | mzimba
# Processing Record 31 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | tura
# Processing Record 34 of Set 5 | honiara
# Processing Record 35 of Set 5 | batagay-alyta
# Processing Record 36 of Set 5 | saskylakh
# Processing Record 37 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | arraial do cabo
# Processing Record 40 of Set 5 | altay
# Processing Record 41 of Set 5 | morgan city
# Processing Record 42 of Set 5 | sao jose da coroa grande
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | outlook
# Processing Record 45 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 5 | luanda
# Processing Record 47 of Set 5 | kangaatsiaq
# Processing Record 48 of Set 5 | opuwo
# Processing Record 49 of Set 5 | xai-xai
# Processing Record 50 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 6 | baikunthpur
# Processing Record 2 of Set 6 | richards bay
# Processing Record 3 of Set 6 | zhigansk
# Processing Record 4 of Set 6 | tecoanapa
# Processing Record 5 of Set 6 | bilma
# Processing Record 6 of Set 6 | fortuna
# Processing Record 7 of Set 6 | belmonte
# Processing Record 8 of Set 6 | iqaluit
# Processing Record 9 of Set 6 | costinesti
# Processing Record 10 of Set 6 | basco
# Processing Record 11 of Set 6 | kieta
# Processing Record 12 of Set 6 | obihiro
# Processing Record 13 of Set 6 | grindavik
# Processing Record 14 of Set 6 | causapscal
# Processing Record 15 of Set 6 | kavieng
# Processing Record 16 of Set 6 | havoysund
# Processing Record 17 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 6 | port elizabeth
# Processing Record 19 of Set 6 | pangody
# Processing Record 20 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 6 | esmeraldas
# Processing Record 22 of Set 6 | lunglei
# Processing Record 23 of Set 6 | royan
# Processing Record 24 of Set 6 | nome
# Processing Record 25 of Set 6 | freeport
# Processing Record 26 of Set 6 | beloha
# Processing Record 27 of Set 6 | olafsvik
# Processing Record 28 of Set 6 | daru
# Processing Record 29 of Set 6 | cayenne
# Processing Record 30 of Set 6 | tezu
# Processing Record 31 of Set 6 | vanimo
# Processing Record 32 of Set 6 | balykshi
# Processing Record 33 of Set 6 | samarai
# Processing Record 34 of Set 6 | meulaboh
# Processing Record 35 of Set 6 | morant bay
# Processing Record 36 of Set 6 | saint-joseph
# Processing Record 37 of Set 6 | kununurra
# Processing Record 38 of Set 6 | college
# Processing Record 39 of Set 6 | katherine
# Processing Record 40 of Set 6 | chuy
# Processing Record 41 of Set 6 | porto torres
# Processing Record 42 of Set 6 | santa rosa
# Processing Record 43 of Set 6 | gambela
# Processing Record 44 of Set 6 | lingyuan
# Processing Record 45 of Set 6 | uusikaupunki
# Processing Record 46 of Set 6 | portobelo
# Processing Record 47 of Set 6 | teguise
# Processing Record 48 of Set 6 | kijang
# Processing Record 49 of Set 6 | aksu
# Processing Record 50 of Set 6 | byron bay
# Processing Record 1 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 7 | saint anthony
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | abalak
# Processing Record 5 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 7 | almaznyy
# Processing Record 7 of Set 7 | lata
# Processing Record 8 of Set 7 | san jose
# Processing Record 9 of Set 7 | hobyo
# Processing Record 10 of Set 7 | qui nhon
# Processing Record 11 of Set 7 | eldorado
# Processing Record 12 of Set 7 | vila
# Processing Record 13 of Set 7 | asau
# Processing Record 14 of Set 7 | antsla
# Processing Record 15 of Set 7 | khorramshahr
# Processing Record 16 of Set 7 | ajaccio
# Processing Record 17 of Set 7 | havre-saint-pierre
# Processing Record 18 of Set 7 | azanka
# Processing Record 19 of Set 7 | karlshamn
# Processing Record 20 of Set 7 | chumikan
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | deputatskiy
# Processing Record 23 of Set 7 | ratnagiri
# Processing Record 24 of Set 7 | lompoc
# Processing Record 25 of Set 7 | goderich
# Processing Record 26 of Set 7 | aberystwyth
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | ji-parana
# City not found. Skipping...
# Processing Record 29 of Set 7 | sitka
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | gayny
# Processing Record 32 of Set 7 | vanavara
# Processing Record 33 of Set 7 | turukhansk
# Processing Record 34 of Set 7 | antofagasta
# Processing Record 35 of Set 7 | temirtau
# Processing Record 36 of Set 7 | kabare
# Processing Record 37 of Set 7 | kuzedeyevo
# Processing Record 38 of Set 7 | williamsport
# Processing Record 39 of Set 7 | tessalit
# Processing Record 40 of Set 7 | rio gallegos
# Processing Record 41 of Set 7 | alta floresta
# Processing Record 42 of Set 7 | vostok
# Processing Record 43 of Set 7 | tsaratanana
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 | mahajanga
# Processing Record 46 of Set 7 | warri
# Processing Record 47 of Set 7 | kodiak
# Processing Record 48 of Set 7 | kyshtovka
# Processing Record 49 of Set 7 | otane
# Processing Record 50 of Set 7 | bay roberts
# Processing Record 1 of Set 8 | okhotsk
# Processing Record 2 of Set 8 | prachuap khiri khan
# Processing Record 3 of Set 8 | buraydah
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | muroto
# Processing Record 6 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | north bend
# Processing Record 9 of Set 8 | bengkulu
# Processing Record 10 of Set 8 | olhao
# Processing Record 11 of Set 8 | hohhot
# Processing Record 12 of Set 8 | cascais
# Processing Record 13 of Set 8 | loralai
# Processing Record 14 of Set 8 | geraldton
# Processing Record 15 of Set 8 | tarrafal
# Processing Record 16 of Set 8 | touba
# Processing Record 17 of Set 8 | allingabro
# Processing Record 18 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 19 of Set 8 | bambous virieux
# Processing Record 20 of Set 8 | kaitangata
# Processing Record 21 of Set 8 | dalvik
# Processing Record 22 of Set 8 | gua musang
# Processing Record 23 of Set 8 | atbasar
# Processing Record 24 of Set 8 | stornoway
# Processing Record 25 of Set 8 | selma
# Processing Record 26 of Set 8 | baijiantan
# Processing Record 27 of Set 8 | mglin
# Processing Record 28 of Set 8 | nyrob
# Processing Record 29 of Set 8 | oksfjord
# Processing Record 30 of Set 8 | cabo san lucas
# Processing Record 31 of Set 8 | amazar
# Processing Record 32 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 8 | vila velha
# Processing Record 34 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 8 | acopiara
# Processing Record 36 of Set 8 | yumen
# Processing Record 37 of Set 8 | susehri
# Processing Record 38 of Set 8 | longford
# Processing Record 39 of Set 8 | diu
# Processing Record 40 of Set 8 | salinopolis
# Processing Record 41 of Set 8 | teneguiban
# City not found. Skipping...
# Processing Record 42 of Set 8 | miri
# Processing Record 43 of Set 8 | jiuquan
# Processing Record 44 of Set 8 | long beach
# Processing Record 45 of Set 8 | kindersley
# Processing Record 46 of Set 8 | port blair
# Processing Record 47 of Set 8 | merauke
# Processing Record 48 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 8 | mastung
# Processing Record 50 of Set 8 | lalibela
# Processing Record 1 of Set 9 | clarence town
# Processing Record 2 of Set 9 | klaksvik
# Processing Record 3 of Set 9 | gizo
# Processing Record 4 of Set 9 | mehamn
# Processing Record 5 of Set 9 | gasa
# Processing Record 6 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 9 | los llanos de aridane
# Processing Record 8 of Set 9 | abu samrah
# Processing Record 9 of Set 9 | abu kamal
# Processing Record 10 of Set 9 | pevek
# Processing Record 11 of Set 9 | ambovombe
# Processing Record 12 of Set 9 | smithers
# Processing Record 13 of Set 9 | manitouwadge
# Processing Record 14 of Set 9 | batangafo
# Processing Record 15 of Set 9 | penjamo
# Processing Record 16 of Set 9 | parabel
# Processing Record 17 of Set 9 | alausi
# Processing Record 18 of Set 9 | vardo
# Processing Record 19 of Set 9 | biltine
# Processing Record 20 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 9 | hami
# Processing Record 22 of Set 9 | enshi
# Processing Record 23 of Set 9 | dayong
# Processing Record 24 of Set 9 | esperance
# Processing Record 25 of Set 9 | bathsheba
# Processing Record 26 of Set 9 | tasiilaq
# Processing Record 27 of Set 9 | iranshahr
# Processing Record 28 of Set 9 | dondo
# Processing Record 29 of Set 9 | plettenberg bay
# Processing Record 30 of Set 9 | viedma
# Processing Record 31 of Set 9 | soe
# Processing Record 32 of Set 9 | groningen
# Processing Record 33 of Set 9 | varhaug
# Processing Record 34 of Set 9 | pacific grove
# Processing Record 35 of Set 9 | almenara
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | fassuta
# Processing Record 38 of Set 9 | maceio
# Processing Record 39 of Set 9 | ye
# City not found. Skipping...
# Processing Record 40 of Set 9 | atambua
# Processing Record 41 of Set 9 | lagunillas
# Processing Record 42 of Set 9 | candido mendes
# Processing Record 43 of Set 9 | cairns
# Processing Record 44 of Set 9 | chauk
# Processing Record 45 of Set 9 | oriximina
# Processing Record 46 of Set 9 | verkhovazhye
# Processing Record 47 of Set 9 | nuuk
# Processing Record 48 of Set 9 | port macquarie
# Processing Record 49 of Set 9 | zhuhai
# Processing Record 50 of Set 9 | hibbing
# Processing Record 1 of Set 10 | yenagoa
# Processing Record 2 of Set 10 | hakvik
# City not found. Skipping...
# Processing Record 3 of Set 10 | conceicao do mato dentro
# Processing Record 4 of Set 10 | norman wells
# Processing Record 5 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 6 of Set 10 | vila franca do campo
# Processing Record 7 of Set 10 | yaan
# Processing Record 8 of Set 10 | abu zabad
# Processing Record 9 of Set 10 | kargasok
# Processing Record 10 of Set 10 | madiun
# Processing Record 11 of Set 10 | tanete
# Processing Record 12 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 10 | avera
# Processing Record 15 of Set 10 | ilheus
# Processing Record 16 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 10 | lady frere
# Processing Record 18 of Set 10 | constitucion
# Processing Record 19 of Set 10 | moa
# Processing Record 20 of Set 10 | bo
# City not found. Skipping...
# Processing Record 21 of Set 10 | mogadishu
# Processing Record 22 of Set 10 | baykit
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | burgeo
# Processing Record 25 of Set 10 | waipawa
# Processing Record 26 of Set 10 | makaha
# Processing Record 27 of Set 10 | tarare
# Processing Record 28 of Set 10 | tawau
# Processing Record 29 of Set 10 | hualmay
# Processing Record 30 of Set 10 | villa maria
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | suao
# City not found. Skipping...
# Processing Record 33 of Set 10 | salalah
# Processing Record 34 of Set 10 | ambunti
# Processing Record 35 of Set 10 | faanui
# Processing Record 36 of Set 10 | mbarara
# Processing Record 37 of Set 10 | sao filipe
# Processing Record 38 of Set 10 | nisia floresta
# Processing Record 39 of Set 10 | calbuco
# Processing Record 40 of Set 10 | maputo
# Processing Record 41 of Set 10 | alugan
# Processing Record 42 of Set 10 | novoilinsk
# Processing Record 43 of Set 10 | linxia
# Processing Record 44 of Set 10 | rancharia
# Processing Record 45 of Set 10 | uaua
# Processing Record 46 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 10 | vanino
# Processing Record 48 of Set 10 | cherskiy
# Processing Record 49 of Set 10 | mount gambier
# Processing Record 50 of Set 10 | ullapool
# Processing Record 1 of Set 11 | tilichiki
# Processing Record 2 of Set 11 | beira
# Processing Record 3 of Set 11 | ulladulla
# Processing Record 4 of Set 11 | erzin
# Processing Record 5 of Set 11 | sobolevo
# Processing Record 6 of Set 11 | sumenep
# Processing Record 7 of Set 11 | otjiwarongo
# Processing Record 8 of Set 11 | verkhniy baskunchak
# Processing Record 9 of Set 11 | chimbote
# Processing Record 10 of Set 11 | raga
# Processing Record 11 of Set 11 | strzelce krajenskie
# Processing Record 12 of Set 11 | benjamin hill
# Processing Record 13 of Set 11 | mikuni
# Processing Record 14 of Set 11 | krasnoselkup
# Processing Record 15 of Set 11 | helena
# Processing Record 16 of Set 11 | sioux lookout
# Processing Record 17 of Set 11 | bom jardim
# Processing Record 18 of Set 11 | namibe
# Processing Record 19 of Set 11 | sisimiut
# Processing Record 20 of Set 11 | cacu
# Processing Record 21 of Set 11 | semirom
# Processing Record 22 of Set 11 | robertson
# Processing Record 23 of Set 11 | sorland
# Processing Record 24 of Set 11 | gazli
# Processing Record 25 of Set 11 | ternate
# Processing Record 26 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 11 | balkanabat
# Processing Record 28 of Set 11 | ishigaki
# Processing Record 29 of Set 11 | bonito
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | sao joao da barra
# Processing Record 32 of Set 11 | edgewater
# Processing Record 33 of Set 11 | atar
# Processing Record 34 of Set 11 | gat
# Processing Record 35 of Set 11 | grants
# Processing Record 36 of Set 11 | ilorin
# Processing Record 37 of Set 11 | san cosme y damian
# Processing Record 38 of Set 11 | tagab
# Processing Record 39 of Set 11 | cervo
# Processing Record 40 of Set 11 | kerema
# Processing Record 41 of Set 11 | benjamin aceval
# Processing Record 42 of Set 11 | spokane
# Processing Record 43 of Set 11 | kysyl-syr
# Processing Record 44 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 45 of Set 11 | matadi
# Processing Record 46 of Set 11 | pangnirtung
# Processing Record 47 of Set 11 | bridgeton
# Processing Record 48 of Set 11 | anadyr
# Processing Record 49 of Set 11 | adeje
# Processing Record 50 of Set 11 | santa vitoria do palmar
# Processing Record 1 of Set 12 | aswan
# Processing Record 2 of Set 12 | fukue
# Processing Record 3 of Set 12 | ventanas
# Processing Record 4 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | point pedro
# Processing Record 6 of Set 12 | mana
# Processing Record 7 of Set 12 | northam
# Processing Record 8 of Set 12 | killybegs
# Processing Record 9 of Set 12 | kupang
# Processing Record 10 of Set 12 | san andres
# Processing Record 11 of Set 12 | padang
# Processing Record 12 of Set 12 | mabaruma
# Processing Record 13 of Set 12 | te anau
# Processing Record 14 of Set 12 | accra
# Processing Record 15 of Set 12 | kushmurun
# Processing Record 16 of Set 12 | yulara
# Processing Record 17 of Set 12 | bowen
# Processing Record 18 of Set 12 | mount darwin
# Processing Record 19 of Set 12 | thinadhoo
# Processing Record 20 of Set 12 | sandnessjoen
# Processing Record 21 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 12 | westport
# Processing Record 23 of Set 12 | torit
# Processing Record 24 of Set 12 | lucapa
# Processing Record 25 of Set 12 | tombouctou
# Processing Record 26 of Set 12 | tuysarkan
# City not found. Skipping...
# Processing Record 27 of Set 12 | scottsbluff
# Processing Record 28 of Set 12 | grootfontein
# Processing Record 29 of Set 12 | arman
# Processing Record 30 of Set 12 | yarmouth
# Processing Record 31 of Set 12 | komsomolskiy
# Processing Record 32 of Set 12 | bodo
# Processing Record 33 of Set 12 | la palma
# Processing Record 34 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 12 | porto novo
# Processing Record 36 of Set 12 | moussoro
# Processing Record 37 of Set 12 | iracoubo
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | karratha
# Processing Record 40 of Set 12 | vagur
# Processing Record 41 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 12 | hesla
# Processing Record 43 of Set 12 | arona
# Processing Record 44 of Set 12 | basoda
# Processing Record 45 of Set 12 | chukhloma
# Processing Record 46 of Set 12 | mandalgovi
# Processing Record 47 of Set 12 | taoudenni
# Processing Record 48 of Set 12 | jertih
# Processing Record 49 of Set 12 | longonjo
# Processing Record 50 of Set 12 | lakatoro
# Processing Record 1 of Set 13 | fallon
# Processing Record 2 of Set 13 | veraval
# Processing Record 3 of Set 13 | mankera
# Processing Record 4 of Set 13 | okato
# Processing Record 5 of Set 13 | hambantota
# Processing Record 6 of Set 13 | cockburn town
# Processing Record 7 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 13 | kavaratti
# Processing Record 9 of Set 13 | ericeira
# Processing Record 10 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 13 | verkhoyansk
# Processing Record 12 of Set 13 | muncar
# Processing Record 13 of Set 13 | san cristobal
# Processing Record 14 of Set 13 | san juan de la maguana
# Processing Record 15 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 16 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 13 | bandrele
# Processing Record 18 of Set 13 | bud
# Processing Record 19 of Set 13 | bako
# Processing Record 20 of Set 13 | bara
# Processing Record 21 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 13 | maple creek
# Processing Record 23 of Set 13 | andselv
# City not found. Skipping...
# Processing Record 24 of Set 13 | lerwick
# Processing Record 25 of Set 13 | haines junction
# Processing Record 26 of Set 13 | puerto del rosario
# Processing Record 27 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 13 | sola
# Processing Record 29 of Set 13 | boyolangu
# Processing Record 30 of Set 13 | abong mbang
# Processing Record 31 of Set 13 | maamba
# Processing Record 32 of Set 13 | llanes
# Processing Record 33 of Set 13 | makat
# Processing Record 34 of Set 13 | dudinka
# Processing Record 35 of Set 13 | mayumba
# Processing Record 36 of Set 13 | sarkand
# Processing Record 37 of Set 13 | broken hill
# Processing Record 38 of Set 13 | gamba
# Processing Record 39 of Set 13 | bocas del toro
# Processing Record 40 of Set 13 | ilulissat
# Processing Record 41 of Set 13 | sao miguel do araguaia
# Processing Record 42 of Set 13 | skegness
# Processing Record 43 of Set 13 | myre
# Processing Record 44 of Set 13 | chulumani
# Processing Record 45 of Set 13 | mezen
# Processing Record 46 of Set 13 | katobu
# Processing Record 47 of Set 13 | nikolayevsk-na-amure
# Processing Record 48 of Set 13 | walvis bay
# Processing Record 49 of Set 13 | high rock
# Processing Record 50 of Set 13 | la romana
# Processing Record 1 of Set 14 | cuamba
# Processing Record 2 of Set 14 | leningradskiy
# Processing Record 3 of Set 14 | bukachacha
# Processing Record 4 of Set 14 | bambanglipuro
# Processing Record 5 of Set 14 | najran
# Processing Record 6 of Set 14 | hachinohe
# Processing Record 7 of Set 14 | codajas
# Processing Record 8 of Set 14 | ahipara
# Processing Record 9 of Set 14 | eyl
# Processing Record 10 of Set 14 | iskateley
# Processing Record 11 of Set 14 | port hawkesbury
# Processing Record 12 of Set 14 | raurkela
# City not found. Skipping...
# Processing Record 13 of Set 14 | porbandar
# Processing Record 14 of Set 14 | wad madani
# Processing Record 15 of Set 14 | bossangoa
# Processing Record 16 of Set 14 | nazilli
# Processing Record 17 of Set 14 | foumbot
# Processing Record 18 of Set 14 | acapulco
# Processing Record 19 of Set 14 | uvira
# Processing Record 20 of Set 14 | sao joao do piaui
# Processing Record 21 of Set 14 | brus laguna
# Processing Record 22 of Set 14 | burica
# City not found. Skipping...
# Processing Record 23 of Set 14 | port hedland
# Processing Record 24 of Set 14 | sydney
# Processing Record 25 of Set 14 | solnechnyy
# Processing Record 26 of Set 14 | naica
# Processing Record 27 of Set 14 | hoopstad
# Processing Record 28 of Set 14 | olga
# Processing Record 29 of Set 14 | marzuq
# Processing Record 30 of Set 14 | koumra
# Processing Record 31 of Set 14 | chur
# Processing Record 32 of Set 14 | talnakh
# Processing Record 33 of Set 14 | teshie
# Processing Record 34 of Set 14 | tateyama
# Processing Record 35 of Set 14 | rocha
# Processing Record 36 of Set 14 | roma
# Processing Record 37 of Set 14 | caohai
# Processing Record 38 of Set 14 | borba
# Processing Record 39 of Set 14 | urengoy
# Processing Record 40 of Set 14 | yeppoon
# Processing Record 41 of Set 14 | botwood
# Processing Record 42 of Set 14 | popondetta
# Processing Record 43 of Set 14 | shamary
# Processing Record 44 of Set 14 | diffa
# Processing Record 45 of Set 14 | tubuala
# Processing Record 46 of Set 14 | moose jaw
# Processing Record 47 of Set 14 | ola
# Processing Record 48 of Set 14 | watertown
# Processing Record 49 of Set 14 | acari
# Processing Record 50 of Set 14 | huancavelica
# Processing Record 1 of Set 15 | ritchie
# Processing Record 2 of Set 15 | port hardy
# City not found. Skipping...
# Processing Record 3 of Set 15 | sovetskiy
# Processing Record 4 of Set 15 | dwarka
# Processing Record 5 of Set 15 | goma
# Processing Record 6 of Set 15 | itoman
# Processing Record 7 of Set 15 | honningsvag
# Processing Record 8 of Set 15 | raahe
# Processing Record 9 of Set 15 | parrita
# Processing Record 10 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 15 | begunitsy
# Processing Record 12 of Set 15 | moba
# Processing Record 13 of Set 15 | mayo
# Processing Record 14 of Set 15 | bubaque
# Processing Record 15 of Set 15 | ixtapa
# Processing Record 16 of Set 15 | todos santos
# Processing Record 17 of Set 15 | tamiahua
# Processing Record 18 of Set 15 | baihar
# Processing Record 19 of Set 15 | kiama
# Processing Record 20 of Set 15 | belaya gora
# Processing Record 21 of Set 15 | chongwe
# Processing Record 22 of Set 15 | dharchula
# Processing Record 23 of Set 15 | santander
# Processing Record 24 of Set 15 | damara
# Processing Record 25 of Set 15 | isiro
# Processing Record 26 of Set 15 | belo horizonte
# Processing Record 27 of Set 15 | san roque
# Processing Record 28 of Set 15 | manicore
# Processing Record 29 of Set 15 | tarakan
# Processing Record 30 of Set 15 | mitsamiouli
# Processing Record 31 of Set 15 | peshkopi
# Processing Record 32 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 15 | bongaree
# Processing Record 34 of Set 15 | vao
# Processing Record 35 of Set 15 | bitam
# Processing Record 36 of Set 15 | santa cruz
# Processing Record 37 of Set 15 | shimoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check the number of cities in list
len(city_data)
# Out:
# 675

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Qaanaaq      GL  77.4840  -69.3632     21.06        72          12
# 1    East London      ZA -33.0153   27.9116     79.74        24           0
# 2       Hamilton      US  39.1834  -84.5333     70.93        90          75
# 3   San Patricio      US  28.0170  -97.5169     76.89        94          15
# 4         Jiwani      PK  25.0500   61.7417     85.60        75           2
# 5        Ushuaia      AR -54.8000  -68.3000     37.06        93          75
# 6   Quatre Cocos      MU -20.2078   57.7625     77.09        77          80
# 7         Manono      CD  -7.3000   27.4167     79.90        37          82
# 8  Berdigestyakh      RU  62.0989  126.6992     47.12        70         100
# 9      Jamestown      US  42.0970  -79.2353     59.85        76          90
#
#    Wind Speed Current Description
# 0        6.51          few clouds
# 1        9.22           clear sky
# 2        2.64       broken clouds
# 3        5.99          few clouds
# 4       14.61           clear sky
# 5       10.36          light rain
# 6       12.88          light rain
# 7       11.61       broken clouds
# 8       12.84          light rain
# 9        3.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
