# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests 
from citipy import citipy
from config import weather_database_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_database_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d12c5a242c476a88e7e9849310b75fdb

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | pangnirtung
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | vanavara
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | bull savanna
# Processing Record 13 of Set 1 | tumkur
# Processing Record 14 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | asau
# Processing Record 20 of Set 1 | xiamen
# Processing Record 21 of Set 1 | san patricio
# Processing Record 22 of Set 1 | aketi
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | bubaque
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | itoman
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | quirinopolis
# Processing Record 31 of Set 1 | flinders
# Processing Record 32 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | kumhari
# Processing Record 35 of Set 1 | yar-sale
# Processing Record 36 of Set 1 | half moon bay
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | huarmey
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | tigre
# Processing Record 43 of Set 1 | shu
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | ucluelet
# Processing Record 46 of Set 1 | paraiso
# Processing Record 47 of Set 1 | norman wells
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | namatanai
# Processing Record 50 of Set 1 | baglung
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 2 | inuvik
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | port hardy
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | kurchum
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | monywa
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | chipurupalle
# Processing Record 14 of Set 2 | olafsvik
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | shelburne
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | bukama
# Processing Record 23 of Set 2 | puerto carreno
# Processing Record 24 of Set 2 | mao
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | cairns
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | puerto leguizamo
# Processing Record 31 of Set 2 | simao
# Processing Record 32 of Set 2 | kumano
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | lagoa
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | iskateley
# Processing Record 39 of Set 2 | biltine
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | katherine
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | villa oliva
# City not found. Skipping...
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | kenai
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | rosetta
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | waingapu
# Processing Record 6 of Set 3 | pakokku
# Processing Record 7 of Set 3 | boden
# Processing Record 8 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | porto velho
# Processing Record 13 of Set 3 | igra
# Processing Record 14 of Set 3 | cozumel
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | tlahualilo
# City not found. Skipping...
# Processing Record 17 of Set 3 | savannah bight
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | sandpoint
# Processing Record 20 of Set 3 | nanortalik
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | nantucket
# Processing Record 23 of Set 3 | gejiu
# Processing Record 24 of Set 3 | murray bridge
# Processing Record 25 of Set 3 | asilah
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | merritt island
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | barstow
# Processing Record 30 of Set 3 | eustis
# Processing Record 31 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | tonantins
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | kingman
# Processing Record 37 of Set 3 | dyadkovskaya
# City not found. Skipping...
# Processing Record 38 of Set 3 | leningradskiy
# Processing Record 39 of Set 3 | kati
# Processing Record 40 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 3 | rudnogorsk
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | byron bay
# Processing Record 44 of Set 3 | maltahohe
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | tiznit
# Processing Record 47 of Set 3 | henderson
# Processing Record 48 of Set 3 | yeniseysk
# Processing Record 49 of Set 3 | samarai
# Processing Record 50 of Set 3 | dingle
# Processing Record 1 of Set 4 | cuamba
# Processing Record 2 of Set 4 | cabo san lucas
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | aklavik
# Processing Record 5 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | kargopol
# Processing Record 8 of Set 4 | tongliao
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | zhigansk
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | havre-saint-pierre
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | san quintin
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | la romana
# Processing Record 18 of Set 4 | nalut
# Processing Record 19 of Set 4 | ibirama
# Processing Record 20 of Set 4 | hermanus
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 4 | los llanos de aridane
# Processing Record 24 of Set 4 | vostok
# Processing Record 25 of Set 4 | luderitz
# Processing Record 26 of Set 4 | villa maria
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | ixtapa
# Processing Record 29 of Set 4 | kuytun
# Processing Record 30 of Set 4 | port elizabeth
# Processing Record 31 of Set 4 | nanakuli
# Processing Record 32 of Set 4 | camopi
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | laguna
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | aktash
# Processing Record 39 of Set 4 | ayagoz
# Processing Record 40 of Set 4 | lakatoro
# Processing Record 41 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 4 | venado tuerto
# Processing Record 43 of Set 4 | vao
# Processing Record 44 of Set 4 | lavrentiya
# Processing Record 45 of Set 4 | sorland
# Processing Record 46 of Set 4 | awjilah
# Processing Record 47 of Set 4 | vardo
# Processing Record 48 of Set 4 | taunggyi
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | caramay
# Processing Record 2 of Set 5 | tepelene
# Processing Record 3 of Set 5 | iisalmi
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | puerto del rosario
# Processing Record 6 of Set 5 | yerbogachen
# Processing Record 7 of Set 5 | mindelo
# Processing Record 8 of Set 5 | broken hill
# Processing Record 9 of Set 5 | ylojarvi
# Processing Record 10 of Set 5 | mandalgovi
# Processing Record 11 of Set 5 | toktogul
# Processing Record 12 of Set 5 | liku
# Processing Record 13 of Set 5 | hutchinson
# Processing Record 14 of Set 5 | linxia
# Processing Record 15 of Set 5 | mbanza-ngungu
# Processing Record 16 of Set 5 | puerto escondido
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | surt
# Processing Record 19 of Set 5 | jalu
# Processing Record 20 of Set 5 | xiaoshi
# Processing Record 21 of Set 5 | harer
# Processing Record 22 of Set 5 | wynyard
# Processing Record 23 of Set 5 | mount isa
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | winneba
# Processing Record 27 of Set 5 | matara
# Processing Record 28 of Set 5 | podor
# Processing Record 29 of Set 5 | vestmannaeyjar
# Processing Record 30 of Set 5 | canico
# Processing Record 31 of Set 5 | rio de janeiro
# Processing Record 32 of Set 5 | solnechnyy
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | avarua
# Processing Record 35 of Set 5 | kathmandu
# Processing Record 36 of Set 5 | canete
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | shihezi
# Processing Record 39 of Set 5 | talas
# Processing Record 40 of Set 5 | ngerengere
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | trinidad
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | krasnoselkup
# Processing Record 45 of Set 5 | hofn
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | nicoya
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | havelock
# Processing Record 1 of Set 6 | shreveport
# Processing Record 2 of Set 6 | marsh harbour
# Processing Record 3 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 6 | buraydah
# Processing Record 5 of Set 6 | gazni
# City not found. Skipping...
# Processing Record 6 of Set 6 | pedernales
# Processing Record 7 of Set 6 | ust-ilimsk
# Processing Record 8 of Set 6 | waw
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | rocky mountain house
# Processing Record 11 of Set 6 | yayva
# Processing Record 12 of Set 6 | praia
# Processing Record 13 of Set 6 | adre
# Processing Record 14 of Set 6 | noumea
# Processing Record 15 of Set 6 | santa cruz
# Processing Record 16 of Set 6 | la rioja
# Processing Record 17 of Set 6 | vidim
# Processing Record 18 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | okhotsk
# Processing Record 21 of Set 6 | isla mujeres
# Processing Record 22 of Set 6 | moron
# Processing Record 23 of Set 6 | alihe
# Processing Record 24 of Set 6 | anisoc
# Processing Record 25 of Set 6 | reyes
# Processing Record 26 of Set 6 | verkhnevilyuysk
# Processing Record 27 of Set 6 | curvelo
# Processing Record 28 of Set 6 | airai
# Processing Record 29 of Set 6 | kamenka
# Processing Record 30 of Set 6 | atambua
# Processing Record 31 of Set 6 | eydhafushi
# Processing Record 32 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 6 | mar del plata
# Processing Record 34 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 36 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 6 | cap malheureux
# Processing Record 38 of Set 6 | bonthe
# Processing Record 39 of Set 6 | roald
# Processing Record 40 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 6 | umm lajj
# Processing Record 42 of Set 6 | naze
# Processing Record 43 of Set 6 | saldanha
# Processing Record 44 of Set 6 | benguela
# Processing Record 45 of Set 6 | kutum
# Processing Record 46 of Set 6 | kayerkan
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | luanda
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | jalpatagua
# Processing Record 1 of Set 7 | cabedelo
# Processing Record 2 of Set 7 | harper
# Processing Record 3 of Set 7 | margate
# Processing Record 4 of Set 7 | mugur-aksy
# Processing Record 5 of Set 7 | kaoma
# Processing Record 6 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | san jose
# Processing Record 9 of Set 7 | ballarat
# Processing Record 10 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 7 | mahebourg
# Processing Record 12 of Set 7 | hadimkoy
# City not found. Skipping...
# Processing Record 13 of Set 7 | feleacu
# Processing Record 14 of Set 7 | kupang
# Processing Record 15 of Set 7 | kaeo
# Processing Record 16 of Set 7 | preobrazheniye
# Processing Record 17 of Set 7 | butaritari
# Processing Record 18 of Set 7 | katsuura
# Processing Record 19 of Set 7 | nioro
# Processing Record 20 of Set 7 | tucumcari
# Processing Record 21 of Set 7 | denpasar
# Processing Record 22 of Set 7 | porto novo
# Processing Record 23 of Set 7 | horasan
# Processing Record 24 of Set 7 | tivaouane
# Processing Record 25 of Set 7 | san isidro
# Processing Record 26 of Set 7 | te anau
# Processing Record 27 of Set 7 | leh
# Processing Record 28 of Set 7 | arosa
# Processing Record 29 of Set 7 | camacha
# Processing Record 30 of Set 7 | baykit
# Processing Record 31 of Set 7 | sungaipenuh
# Processing Record 32 of Set 7 | kibaya
# Processing Record 33 of Set 7 | salalah
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | ola
# Processing Record 36 of Set 7 | uaua
# Processing Record 37 of Set 7 | haines junction
# Processing Record 38 of Set 7 | cherepovets
# Processing Record 39 of Set 7 | saint anthony
# Processing Record 40 of Set 7 | dicabisagan
# Processing Record 41 of Set 7 | komsomolskiy
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | san angelo
# Processing Record 44 of Set 7 | abha
# Processing Record 45 of Set 7 | acacias
# Processing Record 46 of Set 7 | guanica
# Processing Record 47 of Set 7 | birjand
# Processing Record 48 of Set 7 | pangkalanbuun
# Processing Record 49 of Set 7 | consett
# Processing Record 50 of Set 7 | pochutla
# Processing Record 1 of Set 8 | suez
# Processing Record 2 of Set 8 | kurumkan
# Processing Record 3 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 8 | amuntai
# Processing Record 5 of Set 8 | nizhniy kuranakh
# Processing Record 6 of Set 8 | san juan
# Processing Record 7 of Set 8 | ongandjera
# Processing Record 8 of Set 8 | ligayan
# Processing Record 9 of Set 8 | kadoshkino
# Processing Record 10 of Set 8 | ullo
# Processing Record 11 of Set 8 | ambilobe
# Processing Record 12 of Set 8 | nsanje
# Processing Record 13 of Set 8 | natal
# Processing Record 14 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 8 | codrington
# Processing Record 16 of Set 8 | karla
# Processing Record 17 of Set 8 | boditi
# Processing Record 18 of Set 8 | sorong
# Processing Record 19 of Set 8 | constitucion
# Processing Record 20 of Set 8 | bintulu
# Processing Record 21 of Set 8 | thunder bay
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | qaqortoq
# Processing Record 24 of Set 8 | remanso
# Processing Record 25 of Set 8 | newport
# Processing Record 26 of Set 8 | ndele
# Processing Record 27 of Set 8 | tigzirt
# Processing Record 28 of Set 8 | barcarena
# Processing Record 29 of Set 8 | chiredzi
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | kitob
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | grand gaube
# Processing Record 34 of Set 8 | punta umbria
# Processing Record 35 of Set 8 | napasar
# Processing Record 36 of Set 8 | susanville
# Processing Record 37 of Set 8 | sebring
# Processing Record 38 of Set 8 | ihosy
# Processing Record 39 of Set 8 | turkmenabat
# Processing Record 40 of Set 8 | strezhevoy
# Processing Record 41 of Set 8 | meadow lake
# Processing Record 42 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 8 | beringovskiy
# Processing Record 44 of Set 8 | uyar
# Processing Record 45 of Set 8 | osakarovka
# Processing Record 46 of Set 8 | bealanana
# Processing Record 47 of Set 8 | andenes
# Processing Record 48 of Set 8 | mitsamiouli
# Processing Record 49 of Set 8 | klaksvik
# Processing Record 50 of Set 8 | alyangula
# Processing Record 1 of Set 9 | fairbanks
# Processing Record 2 of Set 9 | westport
# Processing Record 3 of Set 9 | san-pedro
# Processing Record 4 of Set 9 | acapulco
# Processing Record 5 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 9 | kurilsk
# Processing Record 7 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 9 | ostrovnoy
# Processing Record 9 of Set 9 | hun
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | batemans bay
# Processing Record 12 of Set 9 | chunskiy
# Processing Record 13 of Set 9 | yinchuan
# Processing Record 14 of Set 9 | syracuse
# Processing Record 15 of Set 9 | banda aceh
# Processing Record 16 of Set 9 | binzhou
# Processing Record 17 of Set 9 | yumen
# Processing Record 18 of Set 9 | sayyan
# Processing Record 19 of Set 9 | beyneu
# Processing Record 20 of Set 9 | dayong
# Processing Record 21 of Set 9 | garibaldi
# Processing Record 22 of Set 9 | ogaminana
# Processing Record 23 of Set 9 | port-gentil
# Processing Record 24 of Set 9 | cam ranh
# Processing Record 25 of Set 9 | cayenne
# Processing Record 26 of Set 9 | pemangkat
# Processing Record 27 of Set 9 | makakilo city
# Processing Record 28 of Set 9 | college
# Processing Record 29 of Set 9 | paoua
# Processing Record 30 of Set 9 | turulung
# Processing Record 31 of Set 9 | homer
# Processing Record 32 of Set 9 | carutapera
# Processing Record 33 of Set 9 | kashary
# Processing Record 34 of Set 9 | shimoda
# Processing Record 35 of Set 9 | tekeli
# Processing Record 36 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 9 | new glasgow
# Processing Record 38 of Set 9 | sham churasi
# Processing Record 39 of Set 9 | makkaveyevo
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 9 | choya
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | franca
# Processing Record 45 of Set 9 | kota kinabalu
# Processing Record 46 of Set 9 | sulangan
# Processing Record 47 of Set 9 | jardim
# Processing Record 48 of Set 9 | clyde river
# Processing Record 49 of Set 9 | egvekinot
# Processing Record 50 of Set 9 | igarka
# Processing Record 1 of Set 10 | mujiayingzi
# Processing Record 2 of Set 10 | borogontsy
# Processing Record 3 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 10 | erzin
# Processing Record 5 of Set 10 | bembereke
# Processing Record 6 of Set 10 | lake ridge
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | itaituba
# Processing Record 9 of Set 10 | manggar
# Processing Record 10 of Set 10 | santana do livramento
# Processing Record 11 of Set 10 | kenora
# Processing Record 12 of Set 10 | gamba
# Processing Record 13 of Set 10 | dudinka
# Processing Record 14 of Set 10 | abashiri
# Processing Record 15 of Set 10 | khani
# Processing Record 16 of Set 10 | badiraguato
# Processing Record 17 of Set 10 | sambava
# Processing Record 18 of Set 10 | rio grande
# Processing Record 19 of Set 10 | rizhao
# Processing Record 20 of Set 10 | kalat
# Processing Record 21 of Set 10 | tautira
# Processing Record 22 of Set 10 | ust-tarka
# Processing Record 23 of Set 10 | aden
# Processing Record 24 of Set 10 | izumo
# Processing Record 25 of Set 10 | valparaiso
# Processing Record 26 of Set 10 | peniche
# Processing Record 27 of Set 10 | lima
# Processing Record 28 of Set 10 | yarada
# Processing Record 29 of Set 10 | belaya gora
# Processing Record 30 of Set 10 | oyama
# Processing Record 31 of Set 10 | sao luiz gonzaga
# Processing Record 32 of Set 10 | atyrau
# Processing Record 33 of Set 10 | kinel-cherkassy
# Processing Record 34 of Set 10 | vitim
# Processing Record 35 of Set 10 | sycamore
# Processing Record 36 of Set 10 | woensdrecht
# Processing Record 37 of Set 10 | sitka
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | caninde de sao francisco
# Processing Record 40 of Set 10 | biu
# Processing Record 41 of Set 10 | arauca
# Processing Record 42 of Set 10 | san javier
# Processing Record 43 of Set 10 | waipawa
# Processing Record 44 of Set 10 | suao
# City not found. Skipping...
# Processing Record 45 of Set 10 | miri
# Processing Record 46 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 10 | dryden
# Processing Record 48 of Set 10 | ciudad bolivar
# Processing Record 49 of Set 10 | ribas do rio pardo
# Processing Record 50 of Set 10 | tikamgarh
# Processing Record 1 of Set 11 | lompoc
# Processing Record 2 of Set 11 | nouadhibou
# Processing Record 3 of Set 11 | sao felix do xingu
# Processing Record 4 of Set 11 | imbituba
# Processing Record 5 of Set 11 | along
# Processing Record 6 of Set 11 | chyhyryn
# Processing Record 7 of Set 11 | mitu
# Processing Record 8 of Set 11 | paarl
# Processing Record 9 of Set 11 | gornyy
# Processing Record 10 of Set 11 | avera
# Processing Record 11 of Set 11 | nyazepetrovsk
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | kindu
# Processing Record 14 of Set 11 | ballina
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | nyurba
# Processing Record 17 of Set 11 | buckeye
# Processing Record 18 of Set 11 | santiago de cao
# Processing Record 19 of Set 11 | coihaique
# Processing Record 20 of Set 11 | chulym
# Processing Record 21 of Set 11 | andilamena
# Processing Record 22 of Set 11 | abu samrah
# Processing Record 23 of Set 11 | khetri
# Processing Record 24 of Set 11 | eyl
# Processing Record 25 of Set 11 | ondjiva
# Processing Record 26 of Set 11 | nhulunbuy
# Processing Record 27 of Set 11 | san carlos de bariloche
# Processing Record 28 of Set 11 | zonguldak
# Processing Record 29 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | tessalit
# Processing Record 31 of Set 11 | mackay
# Processing Record 32 of Set 11 | poronaysk
# Processing Record 33 of Set 11 | farmington
# Processing Record 34 of Set 11 | bowen
# Processing Record 35 of Set 11 | galesong
# Processing Record 36 of Set 11 | barroualie
# City not found. Skipping...
# Processing Record 37 of Set 11 | niquelandia
# Processing Record 38 of Set 11 | hauterive
# Processing Record 39 of Set 11 | kuala terengganu
# Processing Record 40 of Set 11 | guacamayas
# Processing Record 41 of Set 11 | a coruna
# Processing Record 42 of Set 11 | caconda
# Processing Record 43 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 44 of Set 11 | maceio
# Processing Record 45 of Set 11 | afua
# Processing Record 46 of Set 11 | ponta delgada
# Processing Record 47 of Set 11 | bahia blanca
# Processing Record 48 of Set 11 | coro
# Processing Record 49 of Set 11 | kankan
# Processing Record 50 of Set 11 | povenets
# Processing Record 1 of Set 12 | itabira
# Processing Record 2 of Set 12 | yaan
# Processing Record 3 of Set 12 | quatre cocos
# Processing Record 4 of Set 12 | visnes
# Processing Record 5 of Set 12 | iquique
# Processing Record 6 of Set 12 | chapleau
# Processing Record 7 of Set 12 | velikiy novgorod
# Processing Record 8 of Set 12 | faya
# Processing Record 9 of Set 12 | anupgarh
# Processing Record 10 of Set 12 | andalan
# Processing Record 11 of Set 12 | touros
# Processing Record 12 of Set 12 | adrar
# Processing Record 13 of Set 12 | pacifica
# Processing Record 14 of Set 12 | gandhidham
# Processing Record 15 of Set 12 | celestun
# Processing Record 16 of Set 12 | putina
# Processing Record 17 of Set 12 | bela
# Processing Record 18 of Set 12 | sterling
# Processing Record 19 of Set 12 | civitavecchia
# Processing Record 20 of Set 12 | arlit
# Processing Record 21 of Set 12 | roebourne
# Processing Record 22 of Set 12 | krasnyy chikoy
# Processing Record 23 of Set 12 | puerto gaitan
# Processing Record 24 of Set 12 | prince rupert
# Processing Record 25 of Set 12 | santa maria
# Processing Record 26 of Set 12 | iralaya
# Processing Record 27 of Set 12 | terney
# Processing Record 28 of Set 12 | cartagena
# Processing Record 29 of Set 12 | rantauprapat
# Processing Record 30 of Set 12 | jieshi
# Processing Record 31 of Set 12 | oranjemund
# Processing Record 32 of Set 12 | aswan
# Processing Record 33 of Set 12 | tilichiki
# Processing Record 34 of Set 12 | lasa
# Processing Record 35 of Set 12 | nizwa
# Processing Record 36 of Set 12 | waddan
# Processing Record 37 of Set 12 | belmonte
# Processing Record 38 of Set 12 | dire
# Processing Record 39 of Set 12 | aksarka
# Processing Record 40 of Set 12 | saint-augustin
# Processing Record 41 of Set 12 | olga
# Processing Record 42 of Set 12 | srednekolymsk
# Processing Record 43 of Set 12 | marondera
# Processing Record 44 of Set 12 | chake chake
# Processing Record 45 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 12 | menongue
# Processing Record 47 of Set 12 | tumut
# Processing Record 48 of Set 12 | beidao
# Processing Record 49 of Set 12 | sioux lookout
# Processing Record 50 of Set 12 | kidal
# Processing Record 1 of Set 13 | ayan
# Processing Record 2 of Set 13 | pacific grove
# Processing Record 3 of Set 13 | atocha
# Processing Record 4 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 13 | concepcion del oro
# Processing Record 6 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | port lincoln
# Processing Record 8 of Set 13 | cerritos
# Processing Record 9 of Set 13 | sao joao da barra
# Processing Record 10 of Set 13 | nemuro
# Processing Record 11 of Set 13 | kirovskiy
# Processing Record 12 of Set 13 | seoni malwa
# Processing Record 13 of Set 13 | torfyanoy
# Processing Record 14 of Set 13 | padang
# Processing Record 15 of Set 13 | carupano
# Processing Record 16 of Set 13 | ivanteyevka
# Processing Record 17 of Set 13 | acheng
# Processing Record 18 of Set 13 | vallenar
# Processing Record 19 of Set 13 | formosa
# Processing Record 20 of Set 13 | wuning
# Processing Record 21 of Set 13 | ivangorod
# Processing Record 22 of Set 13 | tomatlan
# Processing Record 23 of Set 13 | emmett
# Processing Record 24 of Set 13 | micheweni
# Processing Record 25 of Set 13 | guasdualito
# Processing Record 26 of Set 13 | le port
# Processing Record 27 of Set 13 | svetlaya
# Processing Record 28 of Set 13 | wanderlandia
# City not found. Skipping...
# Processing Record 29 of Set 13 | kalmunai
# Processing Record 30 of Set 13 | narsaq
# Processing Record 31 of Set 13 | upington
# Processing Record 32 of Set 13 | zemio
# Processing Record 33 of Set 13 | kollo
# Processing Record 34 of Set 13 | mulege
# Processing Record 35 of Set 13 | turukhansk
# Processing Record 36 of Set 13 | vanimo
# Processing Record 37 of Set 13 | sapa
# Processing Record 38 of Set 13 | nkhotakota
# Processing Record 39 of Set 13 | mouila
# Processing Record 40 of Set 13 | bauchi
# Processing Record 41 of Set 13 | ulladulla
# Processing Record 42 of Set 13 | sandnessjoen
# Processing Record 43 of Set 13 | kholodnyy
# Processing Record 44 of Set 13 | iracoubo
# Processing Record 45 of Set 13 | deputatskiy
# Processing Record 46 of Set 13 | qiongshan
# Processing Record 47 of Set 13 | ibimirim
# Processing Record 48 of Set 13 | zelenoborsk
# Processing Record 49 of Set 13 | henties bay
# Processing Record 50 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 14 | soyo
# Processing Record 2 of Set 14 | yabelo
# Processing Record 3 of Set 14 | araouane
# Processing Record 4 of Set 14 | vaitape
# Processing Record 5 of Set 14 | san andres
# Processing Record 6 of Set 14 | pringsewu
# Processing Record 7 of Set 14 | tucuman
# Processing Record 8 of Set 14 | burley
# Processing Record 9 of Set 14 | chinu
# Processing Record 10 of Set 14 | awbari
# Processing Record 11 of Set 14 | nauta
# Processing Record 12 of Set 14 | baherden
# Processing Record 13 of Set 14 | frankfort
# Processing Record 14 of Set 14 | springdale
# Processing Record 15 of Set 14 | mabay
# Processing Record 16 of Set 14 | ypsonas
# Processing Record 17 of Set 14 | burnie
# Processing Record 18 of Set 14 | santoshpur
# Processing Record 19 of Set 14 | tarata
# Processing Record 20 of Set 14 | ornskoldsvik
# Processing Record 21 of Set 14 | carstairs
# Processing Record 22 of Set 14 | rio gallegos
# Processing Record 23 of Set 14 | semporna
# Processing Record 24 of Set 14 | lebu
# Processing Record 25 of Set 14 | petatlan
# Processing Record 26 of Set 14 | moree
# Processing Record 27 of Set 14 | tottori
# Processing Record 28 of Set 14 | olenegorsk
# Processing Record 29 of Set 14 | kotido
# Processing Record 30 of Set 14 | sengiley
# Processing Record 31 of Set 14 | sikonge
# Processing Record 32 of Set 14 | mapiri
# Processing Record 33 of Set 14 | kysyl-syr
# Processing Record 34 of Set 14 | port-cartier
# Processing Record 35 of Set 14 | dillon
# Processing Record 36 of Set 14 | mayumba
# Processing Record 37 of Set 14 | shenjiamen
# Processing Record 38 of Set 14 | bobbili
# Processing Record 39 of Set 14 | eureka
# Processing Record 40 of Set 14 | sisimiut
# Processing Record 41 of Set 14 | sanbu
# Processing Record 42 of Set 14 | shaunavon
# Processing Record 43 of Set 14 | bijar
# Processing Record 44 of Set 14 | wattegama
# Processing Record 45 of Set 14 | dzhebariki-khaya
# Processing Record 46 of Set 14 | sarai naurang
# Processing Record 47 of Set 14 | filingue
# Processing Record 48 of Set 14 | yenagoa
# Processing Record 49 of Set 14 | jefferson city
# Processing Record 50 of Set 14 | longonjo
# Processing Record 1 of Set 15 | paita
# Processing Record 2 of Set 15 | mananjary
# Processing Record 3 of Set 15 | bambanglipuro
# Processing Record 4 of Set 15 | meulaboh
# Processing Record 5 of Set 15 | san carlos
# Processing Record 6 of Set 15 | itupiranga
# Processing Record 7 of Set 15 | sobolevo
# Processing Record 8 of Set 15 | santa cruz de la palma
# Processing Record 9 of Set 15 | yefira
# City not found. Skipping...
# Processing Record 10 of Set 15 | rio verde de mato grosso
# Processing Record 11 of Set 15 | xai-xai
# Processing Record 12 of Set 15 | svetlyy
# Processing Record 13 of Set 15 | ucar
# Processing Record 14 of Set 15 | vila
# Processing Record 15 of Set 15 | killybegs
# Processing Record 16 of Set 15 | flin flon
# Processing Record 17 of Set 15 | hearst
# Processing Record 18 of Set 15 | glenwood springs
# Processing Record 19 of Set 15 | bajil
# Processing Record 20 of Set 15 | north bend
# Processing Record 21 of Set 15 | lhokseumawe
# Processing Record 22 of Set 15 | bafq
# Processing Record 23 of Set 15 | dimbokro
# Processing Record 24 of Set 15 | ngama
# Processing Record 25 of Set 15 | huilong
# Processing Record 26 of Set 15 | khor
# Processing Record 27 of Set 15 | rocha
# Processing Record 28 of Set 15 | shirokiy
# Processing Record 29 of Set 15 | letterkenny
# Processing Record 30 of Set 15 | ellisras
# Processing Record 31 of Set 15 | mersing
# Processing Record 32 of Set 15 | port keats
# Processing Record 33 of Set 15 | hokitika
# Processing Record 34 of Set 15 | lufilufi
# Processing Record 35 of Set 15 | high level
# Processing Record 36 of Set 15 | dali
# Processing Record 37 of Set 15 | shubarkuduk
# Processing Record 38 of Set 15 | passos
# Processing Record 39 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 15 | pathein
# Processing Record 41 of Set 15 | belyy
# Processing Record 42 of Set 15 | petukhovo
# Processing Record 43 of Set 15 | agva
# City not found. Skipping...
# Processing Record 44 of Set 15 | zapolyarnyy
# Processing Record 45 of Set 15 | zhezkazgan
# Processing Record 46 of Set 15 | karasuk
# Processing Record 47 of Set 15 | sinnamary
# Processing Record 48 of Set 15 | boffa
# Processing Record 49 of Set 15 | bahir dar
# Processing Record 50 of Set 15 | poum
# Processing Record 1 of Set 16 | corn island
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check the number of cities in list
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
